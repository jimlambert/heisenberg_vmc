# %%
import AnalysisUtls as an
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
files = "../../dat/n4_optvals_ising*"
header, obsAve, obsErr = an.ProcessDataFiles(files, True)

# %%
fs = 30
ls = 20
plt.figure(figsize=(20,10))
#plt.plot(np.arange(0, len(obsAve[0])), obsAve[0], '.')
plt.errorbar(np.arange(0, len(obsAve[0])), obsAve[0], yerr=obsErr[0], marker="d")
plt.xlabel("variational step", fontsize=fs)
plt.ylabel("$<E>$", fontsize=fs)
plt.title("Heisenberg Energy", fontsize=fs)
plt.axhline(y=-9.8)
plt.tick_params(axis='both', which='major', labelsize=ls)
plt.savefig("n10energy_ising.pdf")
plt.show()

# %%
for i in range(0, len(obsAve[0])-1):
    print(i, ":", '\t', obsAve[0][i+1]-obsAve[0][i], '\n')
# Out:
# 0 : 	 -2.332270568561873
#
# 1 : 	 -0.8841760200668897
#
# 2 : 	 -0.10368685618729101
#
# 3 : 	 -0.8619941471571906
#
# 4 : 	 -0.08242816053511692
#
# 5 : 	 -0.01582494983277627
#
# 6 : 	 -0.009154548494983317
#
# 7 : 	 0.0016926755852844089
#
# 8 : 	 -0.0034318729096987077
#
# 9 : 	 0.006620635451504597
#
# 10 : 	 -0.0003561872909698671
#
# 11 : 	 -0.005131939799330798
#
# 12 : 	 0.006136655518394374
#
# 13 : 	 -0.0012224414715715781
#
# 14 : 	 -0.0005301672240802802
#
# 15 : 	 -0.004772274247491826
#
# 16 : 	 0.0018723411371239784
#
# 17 : 	 -0.0005475250836122214
#
# 18 : 	 0.0044604013377926854
#
# 19 : 	 -0.03158481605351149
#
# 20 : 	 0.01680237458193945
#
# 21 : 	 -0.004198394648829318
#
# 22 : 	 0.0024747826086954916
#
# 23 : 	 0.025930066889632286
#
# 24 : 	 -0.01534608695652162
#
# 25 : 	 -0.04427297658862894
#
# 26 : 	 0.06012374581939817
#
# 27 : 	 -0.012797391304347983
#
# 28 : 	 -0.007903143812709068
#
# 29 : 	 -0.008759096989966242
#
# 30 : 	 0.004570936454848962
#
# 31 : 	 -0.0009313377926418731
#
# 32 : 	 0.016766923076922957
#
# 33 : 	 -0.021504581939799206
#
# 34 : 	 -0.0047466555183945935
#
# 35 : 	 0.009807859531772767
#
# 36 : 	 0.013018595317725534
#
# 37 : 	 -0.01675404682274273
#
# 38 : 	 0.004348561872909773
#
# 39 : 	 -0.003166989966555178
#
# 40 : 	 0.0005433779264216732
#
# 41 : 	 0.010719799331103452
#
# 42 : 	 -0.015338461538461523
#
# 43 : 	 0.013295217391304348
#
# 44 : 	 -0.004365652173913048
#
# 45 : 	 0.00018943143812721885
#
# 46 : 	 -0.018096822742474927
#
# 47 : 	 0.03391642140468232
#
# 48 : 	 -0.013270133779264448

# %%
index=1
plt.figure(figsize=(20,10))
#plt.plot(np.arange(0, len(obsAve[0])), obsAve[0], '.')
plt.errorbar(np.arange(0, len(obsAve[index])), obsAve[index], yerr=obsErr[index], marker="d")
plt.xlabel("variational step", fontsize=fs)
plt.ylabel("$<E>$", fontsize=fs)
plt.title(header[index], fontsize=fs)
plt.tick_params(axis='both', which='major', labelsize=ls)
plt.show()

# %%
ls=10
fs=20
x=10
y=6
ms=2

header, data = an.ReadParamsDat("../var_params.dat")
fig, ax = an.PlotVarParams(header, data, 3, fs, ls, ms, x, y,
                           "N$=8$, Ising Model")

plt.savefig("test.pdf", bbox_inches='tight')
