# %%
import AnalysisUtls as an
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
files = "../../vmc-dat/n4obsvals*"
header, obsAve, obsErr = an.ProcessDataFiles(files, True)

# %%
fs = 30
ls = 20
plt.figure(figsize=(20,10))
#plt.plot(np.arange(0, len(obsAve[0])), obsAve[0], '.')
plt.errorbar(np.arange(0, len(obsAve[0])), obsAve[0], yerr=obsErr[0], marker="d")
plt.xlabel("variational step", fontsize=fs)
plt.ylabel("$<E>$", fontsize=fs)
plt.title("Heisenberg Energy", fontsize=fs)
plt.axhline(y=-2.801)
plt.tick_params(axis='both', which='major', labelsize=ls)
plt.savefig("n10energy_ising.pdf")
plt.show()

# %%
index=1
plt.figure(figsize=(20,10))
#plt.plot(np.arange(0, len(obsAve[0])), obsAve[0], '.')
plt.errorbar(np.arange(0, len(obsAve[index])), obsAve[index], yerr=obsErr[index], marker="d")
plt.xlabel("variational step", fontsize=fs)
plt.ylabel("$<E>$", fontsize=fs)
plt.title(header[index], fontsize=fs)
plt.tick_params(axis='both', which='major', labelsize=ls)
plt.show()

# %%
ls=10
fs=20
x=10
y=6
ms=2

header, data = an.ReadParamsDat("../varparams.dat")
fig, ax = an.PlotVarParams(header, data, 3, fs, ls, ms, x, y,
                           "N$=8$, Ising Model")

plt.savefig("test.pdf", bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-04de47289bce> in <module>
#       5 ms=2
#       6
# ----> 7 header, data = an.ReadParamsDat("../varparams.dat")
#       8 fig, ax = an.PlotVarParams(header, data, 3, fs, ls, ms, x, y,
#       9                            "N$=8$, Ising Model")
#
# ~/Documents/Code/heisenberg_vmc/scripts/AnalysisUtls.py in ReadParamsDat(varparFile)
#     120         for line in vF:
#     121             cline = line.strip().split()
# --> 122             cline = [float(x) for x in cline]
#     123             data.append(np.array(cline))
#     124     data=ReshapeData(data)
#
# ~/Documents/Code/heisenberg_vmc/scripts/AnalysisUtls.py in <listcomp>(.0)
#     120         for line in vF:
#     121             cline = line.strip().split()
# --> 122             cline = [float(x) for x in cline]
#     123             data.append(np.array(cline))
#     124     data=ReshapeData(data)
#
# ValueError: could not convert string to float: '(0.2,0)'
